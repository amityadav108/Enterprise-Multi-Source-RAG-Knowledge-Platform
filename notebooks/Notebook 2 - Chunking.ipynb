# %% [markdown]
# ### Install Package:

# %%
# !pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\users\samsung\miniconda3\lib\site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-text-splitters) (1.4.8)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.18)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\samsung\miniconda3\lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\samsung\miniconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\samsung\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\samsung\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\samsung\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\samsung\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: websockets>=15.0 in c:\users\samsung\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\samsung\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\samsung\miniconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.24.0)
# Requirement already satisfied: anyio in c:\users\samsung\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.12.0)
# Requirement already satisfied: certifi in c:\users\samsung\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\samsung\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\users\samsung\miniconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\samsung\miniconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\samsung\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\samsung\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\samsung\miniconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\samsung\miniconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\samsung\miniconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.5.0)

# %% [markdown]
# ### Import Libraries

# %%
import pickle
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %% [markdown]
# ### Load documents.pkl

# %%
with open("data/documents.pkl", "rb") as f:
    documents = pickle.load(f)

print(len(documents))
# Out:
# 6

# %% [markdown]
# ### Initialize Text Splitter

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

# %% [markdown]
# ### Create Text Chunks

# %%
chunks = []

for doc in documents:

    pieces = splitter.split_text(doc["content"])

    for piece in pieces:

        chunks.append({
            "source": doc["source"],
            "text": piece
        })

print("Total Chunks:", len(chunks))
# Out:
# Total Chunks: 6

# %% [markdown]
# ### Preview Sample Chunks

# %%
for chunk in chunks[:5]:

    print("Source:", chunk["source"])
    print(chunk["text"])
    print("-" * 80)
# Out:
# Source: cloud_migration_guide.txt
# Cloud Migration Guide
#
# AWS is the primary cloud platform.
#
# Kubernetes is used for deployment.
#
# GitHub Actions manages CI/CD.
#
# Prometheus and Grafana are used for monitoring.
# --------------------------------------------------------------------------------
# Source: company_policies.txt
# Company Policies
#
# Passwords must be changed every 90 days.
#
# VPN access is mandatory.
#
# Multi-factor authentication is required.
#
# Confidential data should not be shared externally.
# --------------------------------------------------------------------------------
# Source: employee_handbook.txt
# Employee Handbook
#
# Employees receive 20 annual leave days.
#
# Remote work is allowed three days per week.
#
# Working hours are 9 AM to 6 PM.
#
# Health insurance benefits are provided.
# --------------------------------------------------------------------------------
# Source: employees.csv
# EmployeeID     Name      Department  Experience
# 0         101    Alice    Data Science           5
# 1         102      Bob  ML Engineering           3
# 2         103  Charlie              HR           8
# 3         104    David         Finance           6
# 4         105     Emma           Cloud           4
# --------------------------------------------------------------------------------
# Source: products.csv
# ProductID   Product     Category  Price
# 0      P101    Laptop  Electronics    800
# 1      P102     Mouse  Electronics     25
# 2      P103  Keyboard  Electronics     60
# --------------------------------------------------------------------------------

# %% [markdown]
# ### Save chunks.pkl

# %%
with open("data/chunks.pkl", "wb") as f:
    pickle.dump(chunks, f)

print("chunks.pkl saved successfully!")
# Out:
# chunks.pkl saved successfully!

# %% [markdown]
# ### Verify Output

# %%
print("Final Number of Chunks:", len(chunks))
# Out:
# Final Number of Chunks: 6
