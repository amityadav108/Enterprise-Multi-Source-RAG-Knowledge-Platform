# %% [markdown]
# This notebook creates:
#
# * requirements.txt
# * Dockerfile
# * .gitignore
# * README.md
#
# Professional folder structure

# %% [markdown]
# ### Create Project Folders

# %%
from pathlib import Path

folders = [
    "data",
    "outputs",
    "notebooks"
]

for folder in folders:
    Path(folder).mkdir(exist_ok=True)

print("Folders created successfully!")
# Out:
# Folders created successfully!

# %% [markdown]
# ###  Create requirements.txt

# %%
requirements = """
fastapi
uvicorn
numpy
pandas
scikit-learn
faiss-cpu
pypdf
"""

with open("requirements.txt", "w") as f:
    f.write(requirements.strip())

print("requirements.txt created!")
# Out:
# requirements.txt created!

# %% [markdown]
# ### Create Dockerfile

# %%
dockerfile = """
FROM python:3.11

WORKDIR /app

COPY . .

RUN pip install --no-cache-dir -r requirements.txt

EXPOSE 8000

CMD ["uvicorn", "app:app", "--host", "0.0.0.0", "--port", "8000"]
"""

with open("Dockerfile", "w") as f:
    f.write(dockerfile.strip())

print("Dockerfile created!")
# Out:
# Dockerfile created!

# %% [markdown]
# ### Create .gitignore

# %%
gitignore_content = """
__pycache__/
.ipynb_checkpoints/

*.pyc
*.pyo

data/*.pkl
data/*.bin

.env
"""

with open(".gitignore", "w") as f:
    f.write(gitignore_content)

print(".gitignore created successfully!")
# Out:
# .gitignore created successfully!

# %% [markdown]
# ### Verify

# %%
import os

print(os.listdir())
# Out:
# ['.gitignore', '.ipynb_checkpoints', 'app.py', 'data', 'Dockerfile', 'Notebook 1 - Data Ingestion.ipynb', 'Notebook 2 - Chunking.ipynb', 'Notebook 3 - Embeddings + FAISS Vector Database.ipynb', 'Notebook 4 - RAG Question Answering Pipeline.ipynb', 'Notebook 5 - Conversation Memory + Chat History.ipynb', 'Notebook 6 - FastAPI Backend.ipynb', 'Notebook 7 - Docker + requirements.txt + Professional Project Structure.ipynb', 'notebooks', 'outputs', 'README.md', 'requirements.txt', '__pycache__']

# %% [markdown]
# ### Create README.md

# %%
readme = """
# Enterprise Multi-Source RAG Knowledge Platform

## Overview

A production-style Retrieval-Augmented Generation (RAG) system capable of answering questions from multiple enterprise data sources.

Supported Sources:
- PDFs
- CSV files

Tech Stack:
- Python
- FastAPI
- FAISS
- Scikit-learn
- Pandas

Features:
- Multi-source document ingestion
- Chunking pipeline
- Vector search using FAISS
- Citation-based responses
- Conversation memory
- REST APIs with FastAPI
- Swagger documentation

Project Structure:

Enterprise Multi-Source RAG Knowledge Platform/
│
├── app.py
├── requirements.txt
├── Dockerfile
├── README.md
├── data/
├── outputs/
├── notebooks/
└── notebooks 1-7
"""

with open("README.md", "w", encoding="utf-8") as f:
    f.write(readme)

print("README.md created!")
# Out:
# README.md created!

# %% [markdown]
# ###  Verify Files

# %%
import os

for file in os.listdir():
    print(file)
# Out:
# .gitignore
# .ipynb_checkpoints
# app.py
# data
# Dockerfile
# Notebook 1 - Data Ingestion.ipynb
# Notebook 2 - Chunking.ipynb
# Notebook 3 - Embeddings + FAISS Vector Database.ipynb
# Notebook 4 - RAG Question Answering Pipeline.ipynb
# Notebook 5 - Conversation Memory + Chat History.ipynb
# Notebook 6 - FastAPI Backend.ipynb
# Notebook 7 - Docker + requirements.txt + Professional Project Structure.ipynb
# notebooks
# outputs
# README.md
# requirements.txt
# __pycache__

# %%
import os

print(os.listdir("data"))
# Out:
# ['chunks.pkl', 'csv', 'documents.pkl', 'embeddings.npy', 'faiss_index.bin', 'metadata.pkl', 'pdfs', 'text_docs', 'vectorizer.pkl']
